# %%
# !python compress.py -i demo/input/ -o demo/compressed/ -m checkpoints/videocompressor1024.pkl -f 101
# Out:
# 2021-08-15 16:36:45.130691: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-08-15 16:36:45.165888: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc593680990 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-08-15 16:36:45.165915: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Actual_bpp = 0.07612179
# Actual_bpp = 0.10977564
# Actual_bpp = 0.11794872
# Actual_bpp = 0.12291667
# Actual_bpp = 0.12291667
# Actual_bpp = 0.12964744
# Actual_bpp = 0.13894231
# Actual_bpp = 0.14166667
# Actual_bpp = 0.14791667
# Actual_bpp = 0.16089744
# Actual_bpp = 0.15897436
# Actual_bpp = 0.15336538
# Actual_bpp = 0.15016026
# Actual_bpp = 0.14455128
# Actual_bpp = 0.15625000
# Actual_bpp = 0.15432692
# Actual_bpp = 0.15961538
# Actual_bpp = 0.15865385
# Actual_bpp = 0.15913462
# ...

# %%
# !python decompress.py -i demo/compressed/ -o demo/reconstructed -m checkpoints/videocompressor1024.pkl -f 101

# %%
# !python train.py -h
# Out:
# usage: train.py [-h] [--chkfile CHKFILE] [--pklfile PKLFILE] [--input INPUT]
#                 [--frequency FREQUENCY] [--lamda LAMDA] [--restore]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --chkfile CHKFILE, -c CHKFILE
#                         Checkpointing file Default=`checkpoints/videocomp.chk`
#   --pklfile PKLFILE, -p PKLFILE
#                         Pkl file to save weights of the trained network
#                         Default=`checkpoints/videocomp.pkl`
#   --input INPUT, -i INPUT
#                         Directory where training data lie. The structure of
#                         the directory should be like:
#                         vimeo_septuplet/sequences/00001/
#                         vimeo_septuplet/sequences/00002
#                         ............................... For each
#                         vimeo_septuplet/sequences/x there should be subfolders
# ...

# %%
# !python fine_tune.py -c checkpoints_finetune/videocomp.chk -p checkpoints_finetune/videocompressor1024.pkl -i finetune_data/sequences/
# Out:
# Starting
# Starting Session
# lr=0.0001, lambda = 4096
# fine_tune_i: 0
# video_batch: 0
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# recon loss = 0.00075275, bpp = 0.18812951, video = 0, directory = 1
# fine_tune_i: 1
# video_batch: 0
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# recon loss = 0.00069908, bpp = 0.18870066, video = 0, directory = 1
# fine_tune_i: 2
# video_batch: 0
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# recon loss = 0.00066231, bpp = 0.19113380, video = 0, directory = 1

# %%
# !python fine_tune.py -c checkpoints_finetune/videocomp.chk -p checkpoints_finetune/videocompressor1024.pkl -i finetune_data/sequences/ -r

# %%
# !python compress.py -i demo/input/ -o demo/compressed_2/ -m checkpoints_finetune/videocompressor1024.pkl -f 101
# Out:
# Actual_bpp = 0.08910256
# Actual_bpp = 0.12596154
# Actual_bpp = 0.13429487
# Actual_bpp = 0.14006410
# Actual_bpp = 0.13541667
# Actual_bpp = 0.14727564
# Actual_bpp = 0.16201923
# Actual_bpp = 0.16746795
# Actual_bpp = 0.17708333
# Actual_bpp = 0.18509615
# Actual_bpp = 0.18076923
# Actual_bpp = 0.18477564
# Actual_bpp = 0.17275641
# Actual_bpp = 0.17804487
# Actual_bpp = 0.18076923
# Actual_bpp = 0.18076923
# Actual_bpp = 0.18974359
# Actual_bpp = 0.18173077
# Actual_bpp = 0.19198718
# Actual_bpp = 0.19022436
# Actual_bpp = 0.18525641
# Actual_bpp = 0.19951923
# Actual_bpp = 0.19871795
# Actual_bpp = 0.20208333
# Actual_bpp = 0.20657051
# Actual_bpp = 0.20448718
# Actual_bpp = 0.21137821
# Actual_bpp = 0.20544872
# Actual_bpp = 0.21442308
# Actual_bpp = 0.21185897
# Actual_bpp = 0.21955128
# Actual_bpp = 0.22067308
# Actual_bpp = 0.21682692
# Actual_bpp = 0.22419872
# Actual_bpp = 0.22612179
# Actual_bpp = 0.22067308
# Actual_bpp = 0.22804487
# Actual_bpp = 0.22660256
# ...

# %%
# !python decompress.py -i demo/compressed_2/ -o demo/reconstructed_2 -m checkpoints_finetune/videocompressor1024.pkl -f 101
